# %%
from google.colab import drive
drive.mount('/content/gdrive/')

# %%
# !pip3 install piexif

# %%
# %cd /content/gdrive/MyDrive/TrackNetv2/

# %%
#python3 train_TrackNet3.py --load_weights=<previousWeightPath> --save_weights=<weightPath> --dataDir=<npyDataDirectory> --epochs=<trainingEpochs> --tol=<toleranceValue>
# !python3 train_TrackNet3.py --save_weights=mymodel --dataDir=npy --epochs=40 --tol=5
