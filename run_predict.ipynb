# %%
from google.colab import drive
drive.mount('/content/gdrive/')

# %%
# %cd /content/gdrive/MyDrive/TrackNetv2/

# %%
# !pip3 install piexif

# %%
#python3 predict.py --video_name = <videoPath> --load_weights = <weightPath> --label = <csvFile> --tol = <toleranceValue>
# !python3 predict.py --video_name=test_data/1_02_03.mp4 --load_weights=trash_model --label=test_data/1_02_03_ball.csv --tol=5
